# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_excel(r'C:\Users\Sourav\Downloads\Data Viz Dataset.xlsx')

# %%
df.head()
# Out:
#                                              College  \
# 0                                              JDIET
# 1  Indian Institute of Information Technology Des...
# 2                   Manipal Institute of technology
# 3                     Delhi Technological Univeesity
# 4                       Jabalpur Engineering College
#
#    Flutter (skill out of 5)  Flask (skill out of 5)  \
# 0                       2.0                     4.0
# 1                       4.0                     1.0
# 2                       2.0                     2.0
# 3                       NaN                     4.0
# 4                       2.0                     2.0
#
#    Firebase (skill out of 5)  GCP (skill out of 5)  AWS (skill out of 5)  \
# 0                        4.0                   1.0                   1.0
# 1                        1.0                   3.0                   1.0
# 2                        2.0                   1.0                   1.0
# ...

# %%
df.describe()
# Out:
#        Flutter (skill out of 5)  Flask (skill out of 5)  \
# count                138.000000              136.000000
# mean                   1.768116                1.992647
# std                    1.082642                1.125439
# min                    1.000000                1.000000
# 25%                    1.000000                1.000000
# 50%                    1.000000                2.000000
# 75%                    2.750000                3.000000
# max                    5.000000                5.000000
#
#        Firebase (skill out of 5)  GCP (skill out of 5)  AWS (skill out of 5)  \
# count                 138.000000            132.000000            130.000000
# mean                    1.992754              1.643939              1.884615
# std                     1.117194              0.925735              1.008757
# min                     1.000000              1.000000              1.000000
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   College                                155 non-null    object
#  1   Flutter (skill out of 5)               138 non-null    float64
#  2   Flask (skill out of 5)                 136 non-null    float64
#  3   Firebase (skill out of 5)              138 non-null    float64
#  4   GCP (skill out of 5)                   132 non-null    float64
#  5   AWS (skill out of 5)                   130 non-null    float64
#  6   Predictive Modelling (skill out of 5)  144 non-null    float64
#  7   EDA (skill out of 5)                   144 non-null    float64
#  8   NLP (skill out of 5)                   135 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 11.0+ KB
# College                                   0
# ...

# %%
print(f'Number of universities:{df.shape[0]}\nNumber of technologies:{df.shape[1]}')
# Out:
# Number of universities:155
# Number of technologies:9

# %%
#df.applymap(lambda x:1 if x==np.nan else x)
df.fillna(1,inplace=True)
df.head()
# Out:
#                                              College  \
# 0                                              JDIET
# 1  Indian Institute of Information Technology Des...
# 2                   Manipal Institute of technology
# 3                     Delhi Technological Univeesity
# 4                       Jabalpur Engineering College
#
#    Flutter (skill out of 5)  Flask (skill out of 5)  \
# 0                       2.0                     4.0
# 1                       4.0                     1.0
# 2                       2.0                     2.0
# 3                       1.0                     4.0
# 4                       2.0                     2.0
#
#    Firebase (skill out of 5)  GCP (skill out of 5)  AWS (skill out of 5)  \
# 0                        4.0                   1.0                   1.0
# 1                        1.0                   3.0                   1.0
# 2                        2.0                   1.0                   1.0
# ...

# %%
# %matplotlib inline
'''fig,ax=plt.subplots(1)
def helper(start,end):
    df.iloc[start:end].plot.bar(title='Distribution',
                           figsize=(16,17),
                           subplots=True,
                           sharex=True,
                           sharey=False,
                           ax=ax)

    plt.xticks(range(start,end),df.College[start:end])'''

#helper(0,40)
df.iloc[0:40].plot.bar(title='Distribution',
                           figsize=(16,17),
                           subplots=True,
                           sharex=True,
                           sharey=False,
                           )

plt.xticks(range(0,40),df.College[0:40])

plt.show()

# %%
gitam=df[df.College=='Gitam university, Vizag']
gitam.index=gitam.College

# %%
print('Percenatage of NLP in',((gitam['NLP (skill out of 5)']/gitam.sum(axis=1))*100))
# Out:
# Percenatage of NLP in College
# Gitam university, Vizag    12.5
# dtype: float64

# %%
df.College.nunique()
df.loc[0][0]
# Out:
# 'JDIET'
